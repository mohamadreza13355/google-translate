# %%
from deep_translator import GoogleTranslator

# %%
text = input("کلمه رو وارد کن ؟")
if text=="":
    print("NOON")
else:
    print("en → انگلیسی")
    print("ar → عربی")
    print("tr → ترکی")
    print("fr → فرانسه")
    print("de → آلمانی")
    print("es → اسپانیایی")
    print("ru → روسی")
    print("ja → ژاپنی")
    print("****")
     
language = input("زبان مورد نظر را وارد کنید ؟") 
en = GoogleTranslator(source="auto" , target=language).translate(text)
print(en)
# Out:
# en → انگلیسی
# ar → عربی
# tr → ترکی
# fr → فرانسه
# de → آلمانی
# es → اسپانیایی
# ru → روسی
# ja → ژاپنی
# ****
# preliminary
